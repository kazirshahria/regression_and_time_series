# %%
import pandas as pd
import os
import seaborn as sns
from matplotlib import pyplot as plt

# %%
path = os.path.join(os.getcwd(), "datasets", "extra", "properties.csv")
df = pd.read_csv(path, index_col=[0])
df.head()
# Out:
#    Annual Revenue    ADR  Occupancy %  Guests    Status       Status Detail  \
# 0         51908.0  182.0         0.78     8.0  For Rent  Apartment For Rent
# 1         46442.0  181.0         0.70     6.0  For Rent  Apartment For Rent
# 2         64235.0  281.0         0.63    10.0  For Rent  Apartment For Rent
# 3             NaN    NaN          NaN     NaN  For Rent            For Rent
# 4         63984.0  223.0         0.79     8.0  For Rent  Apartment For Rent
#
#     Price  Price Change Date Changed         Street Address  ...  \
# 0  2795.0           NaN          NaN  (undisclosed Address)  ...
# 1  2800.0           NaN          NaN      64-07 68th Ave #2  ...
# 2  5500.0           NaN          NaN       1375 232nd St #4  ...
# 3     NaN           NaN          NaN    221-08 64th Ave # 1  ...
# 4  2695.0           NaN          NaN   5327 73rd St #1RIGHT  ...
#
#   Rent Zestimate Tax Assessed Value  HDP Price  Lot Area  Lot Area Unit  \
# 0         2756.0                NaN     2795.0       NaN            NaN
# 1            NaN                NaN     2800.0       NaN            NaN
# 2            NaN                NaN     5500.0       NaN            NaN
# 3            NaN                NaN        NaN       NaN            NaN
# 4            NaN                NaN     2695.0       NaN            NaN
#
#                 Broker Name Days on Zillow  \
# 0  Charles Rutenberg Realty           0.00
# 1  Realty One Group Dynasty           0.04
# 2                       NaN           0.08
# 3                       NaN           0.00
# 4   BLT MINIMAX REALTY INC.           0.12
#
#                                                  URL   Latitude  Longitude
# 0  https://www.zillow.com/homedetails/Bayside-NY-...        NaN        NaN
# 1  https://www.zillow.com/homedetails/64-07-68th-...  40.705933 -73.894196
# 2  https://www.zillow.com/homedetails/1375-232nd-...  40.681030 -73.734344
# 3  https://www.zillow.com/b/221-08-64th-ave-oakla...        NaN        NaN
# 4  https://www.zillow.com/homedetails/5327-73rd-S...  40.730488 -73.890560
#
# [5 rows x 30 columns]

# %%
cor = df.corr(numeric_only=True)
plt.figure(figsize=(20, 8))
sns.heatmap(cor, annot=True)
plt.show()
